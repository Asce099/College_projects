# %% [markdown]
# # Removing Stopwords

# %%
import nltk
from nltk.corpus import stopwords

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
stops1 = set(stopwords.words('english'))
print(stops1)
# Out:
# {"wouldn't", 'such', 'his', 'about', 'any', 'very', 'hasn', "you'd", 'ma', 'an', 'few', 'wasn', 'my', 'needn', 'there', "weren't", 'whom', "you're", 'her', 'until', 'y', 'doesn', "mightn't", 'own', 'which', 'on', "that'll", 'will', 'all', 'had', 'off', 'in', 'most', 'no', 'each', 'where', 'them', 'they', "should've", 'ain', 'to', 'who', 'i', 'did', 'themselves', 'against', 'only', 'up', 'didn', 'now', 'not', 'was', 'or', "shan't", "wasn't", 'myself', 'our', 'am', 'because', 'when', 'you', 'himself', 'as', 'weren', 'doing', 'over', 'itself', 'your', 'this', 'under', 'below', "needn't", 'by', 'wouldn', 'into', 'out', 'further', "aren't", 'were', 'm', "doesn't", "couldn't", 'be', 'other', 'shouldn', 'is', "don't", 'mightn', 'these', "you'll", 'that', 'the', 'why', 'between', 'down', 't', 'me', 'don', 'a', 'after', 'o', 'while', 'then', "shouldn't", 'yourselves', 'through', 're', 'ours', 'same', 'he', 'mustn', "didn't", 've', 'during', 'being', 'both', 'of', 'couldn', 'can', 'll', 'ourse
# ...

# %%
stops2 = set(stopwords.words('german'))
print(stops2)
'''
stops3 = set(stopwords.words('indonesia'))
stops4 = set(stopwords.words('portuguese'))
stops5 = set(stopwords.words('spanish'))
'''
# Out:
# {'würde', 'welcher', 'bei', 'ihre', 'an', 'auf', 'man', 'mit', 'jener', 'dies', 'viel', 'seines', 'habe', 'solchen', 'eine', 'ihrer', 'anderen', 'nach', 'und', 'meinen', 'seinen', 'weil', 'ihren', 'im', 'das', 'eurem', 'hier', 'einigem', 'will', 'gewesen', 'welche', 'in', 'hab', 'den', 'da', 'vom', 'ander', 'denselben', 'nur', 'kein', 'seinem', 'solcher', 'welchem', 'aller', 'deiner', 'keine', 'einiger', 'uns', 'keiner', 'anderer', 'ihres', 'einmal', 'wo', 'unsere', 'anderes', 'ob', 'hatten', 'eure', 'solches', 'muss', 'ihr', 'mein', 'durch', 'hinter', 'noch', 'doch', 'als', 'sondern', 'auch', 'eures', 'manche', 'war', 'ihm', 'können', 'was', 'waren', 'am', 'einigen', 'jedem', 'bin', 'euch', 'deinen', 'mir', 'dich', 'wird', 'solchem', 'dort', 'haben', 'werden', 'einiges', 'unter', 'würden', 'könnte', 'meines', 'zwischen', 'hatte', 'keinem', 'meine', 'zur', 'sie', 'anders', 'unserem', 'wollte', 'einig', 'nichts', 'der', 'jeder', 'hin', 'wollen', 'bis', 'für', 'weiter', 'bist', 'wie', 
# ...

# %%
from os import path

# %%
gunviobL = open('C:/Users/Ajey Kumar/Desktop/TA/gunviolencebill.txt').read().lower()

# %%
gunviobL
# Out:
# 'us senate passes landmark gun violence bill, house passage is next\nthe us senate approved a bipartisan gun violence bill on thursday in response to the run of brutal mass shootings. the measure would toughen background checks for youngest gun buyers and keep firearms away from more domestic violence offenders.\n\nthe senate easily approved a bipartisan gun violence bill on thursday that seemed unthinkable a month ago, setting up final approval of what will be congressâ€™ most far-reaching response in decades to the nationâ€™s run of brutal mass shootings.\n\n\nafter years of gop procedural delays that derailed democratic efforts to curb firearms, democrats and 15 republicans decided that congressional inaction was untenable after last monthâ€™s rampages in new york and texas. it took weeks of closed-door talks but a bargainers from both parties emerged with a compromise embodying incremental but impactful movement to curb bloodshed that has come to regularly shock â€” yet no longer
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
words = word_tokenize(gunviobL)
wordsFiltered = []

# %%
for w in words:
    if w not in stops1:
        wordsFiltered.append(w)

print(wordsFiltered)
# Out:
# ['us', 'senate', 'passes', 'landmark', 'gun', 'violence', 'bill', ',', 'house', 'passage', 'next', 'us', 'senate', 'approved', 'bipartisan', 'gun', 'violence', 'bill', 'thursday', 'response', 'run', 'brutal', 'mass', 'shootings', '.', 'measure', 'would', 'toughen', 'background', 'checks', 'youngest', 'gun', 'buyers', 'keep', 'firearms', 'away', 'domestic', 'violence', 'offenders', '.', 'senate', 'easily', 'approved', 'bipartisan', 'gun', 'violence', 'bill', 'thursday', 'seemed', 'unthinkable', 'month', 'ago', ',', 'setting', 'final', 'approval', 'congressâ€™', 'far-reaching', 'response', 'decades', 'nationâ€™s', 'run', 'brutal', 'mass', 'shootings', '.', 'years', 'gop', 'procedural', 'delays', 'derailed', 'democratic', 'efforts', 'curb', 'firearms', ',', 'democrats', '15', 'republicans', 'decided', 'congressional', 'inaction', 'untenable', 'last', 'monthâ€™s', 'rampages', 'new', 'york', 'texas', '.', 'took', 'weeks', 'closed-door', 'talks', 'bargainers', 'parties', 'emerged', 'compro
# ...

# %%
#Adding your oun Stopwords
stops1.append("your_stopwords")

# %% [markdown]
# # using Spacy

# %%
import spacy

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
stopwords = nlp.Defaults.stop_words

print(len(stopwords))
print(stopwords)
# Out:
# 326
# ...

# %%
doc2=nlp(gunviobL)

# %%
for token in doc2:
    print(token.text,token.is_stop)
# Out:
# us True
# senate False
# passes False
# landmark False
# gun False
# violence False
# bill False
# , False
# house False
# passage False
# is True
# next True
#
#  False
# the True
# us True
# senate False
# approved False
# a True
# bipartisan False
# gun False
# violence False
# bill False
# on True
# thursday False
# in True
# response False
# to True
# the True
# run False
# of True
# brutal False
# mass False
# shootings False
# . False
# the True
# measure False
# would True
# toughen False
# background False
# checks False
# for True
# youngest False
# gun False
# buyers False
# and True
# keep True
# firearms False
# away False
# from True
# more True
# domestic False
# violence False
# offenders False
# . False
#
#
#  False
# the True
# senate False
# easily False
# approved False
# a True
# bipartisan False
# gun False
# violence False
# bill False
# on True
# thursday False
# that True
# seemed True
# unthinkable False
# a True
# month False
# ago False
# , False
# ...

# %%
lst=[]
for token in text.split():
    if token.lower() not in stopwords:    #checking whether the word is not 
        lst.append(token)

# %%
lst=[]
for token in doc2:
    if token.text not in stopwords:    #checking whether the word is not 
        lst.append(token.text)

# %%
lst
# Out:
# ['senate',
#  'passes',
#  'landmark',
#  'gun',
#  'violence',
#  'bill',
#  ',',
#  'house',
#  'passage',
#  '\n',
#  'senate',
#  'approved',
#  'bipartisan',
#  'gun',
#  'violence',
#  'bill',
#  'thursday',
#  'response',
#  'run',
#  'brutal',
#  'mass',
#  'shootings',
#  '.',
#  'measure',
#  'toughen',
#  'background',
#  'checks',
#  'youngest',
#  'gun',
#  'buyers',
#  'firearms',
#  'away',
#  'domestic',
#  'violence',
#  'offenders',
#  '.',
#  '\n\n',
#  'senate',
#  'easily',
#  'approved',
#  'bipartisan',
#  'gun',
#  'violence',
#  'bill',
#  'thursday',
#  'unthinkable',
#  'month',
#  'ago',
#  ',',
#  'setting',
#  'final',
#  'approval',
#  'congressâ€',
#  '™',
#  'far',
#  '-',
#  'reaching',
#  'response',
#  'decades',
#  'nationâ€',
#  '™',
#  's',
#  'run',
#  'brutal',
#  'mass',
#  'shootings',
#  '.',
#  '\n\n\n',
#  'years',
#  'gop',
#  'procedural',
#  'delays',
#  'derailed',
#  'democratic',
#  'efforts',
#  'curb',
#  'firearms',
#  ',',
# ...

# %%
you can also add your own list of stopwords and delete

# %% [markdown]
# # Using Textblob

# %%
from textblob import TextBlob
from nltk.corpus import stopwords

# %%
wiki = TextBlob(gunviobL)
wiki
# Out:
# TextBlob("us senate passes landmark gun violence bill, house passage is next
# the us senate approved a bipartisan gun violence bill on thursday in response to the run of brutal mass shootings. the measure would toughen background checks for youngest gun buyers and keep firearms away from more domestic violence offenders.
#
# the senate easily approved a bipartisan gun violence bill on thursday that seemed unthinkable a month ago, setting up final approval of what will be congressâ€™ most far-reaching response in decades to the nationâ€™s run of brutal mass shootings.
#
#
# ...

# %%
wiki.words
# Out:
# WordList(['us', 'senate', 'passes', 'landmark', 'gun', 'violence', 'bill', 'house', 'passage', 'is', 'next', 'the', 'us', 'senate', 'approved', 'a', 'bipartisan', 'gun', 'violence', 'bill', 'on', 'thursday', 'in', 'response', 'to', 'the', 'run', 'of', 'brutal', 'mass', 'shootings', 'the', 'measure', 'would', 'toughen', 'background', 'checks', 'for', 'youngest', 'gun', 'buyers', 'and', 'keep', 'firearms', 'away', 'from', 'more', 'domestic', 'violence', 'offenders', 'the', 'senate', 'easily', 'approved', 'a', 'bipartisan', 'gun', 'violence', 'bill', 'on', 'thursday', 'that', 'seemed', 'unthinkable', 'a', 'month', 'ago', 'setting', 'up', 'final', 'approval', 'of', 'what', 'will', 'be', 'congressâ€™', 'most', 'far-reaching', 'response', 'in', 'decades', 'to', 'the', 'nationâ€™s', 'run', 'of', 'brutal', 'mass', 'shootings', 'after', 'years', 'of', 'gop', 'procedural', 'delays', 'that', 'derailed', 'democratic', 'efforts', 'to', 'curb', 'firearms', 'democrats', 'and', '15', 'republicans', 
# ...

# %%
tokenTb=set(wiki.words)

# %%
print("Stopword free Tokens: ",tokenTb-stops1)
# Out:
# Stopword free Tokens:  {'loud', 'considered', 'josh', 'bill', 'bargainers', 'license', 'opposition', 'â€œthe', 'leaving', 'curb', 'senateâ€™s', 'â€œa', 'music', 'drives', 'backed', 'â€', 'nation', 'steve', 'required', 'statement', '65-33', 'right', 'safe', '2026', 'landmark', 'residents', 'response', 'shock', 'victims', 'come', 'arms', 'â€œbut', 'mental', 'action', 'house', '20', 'regularly', 'lisa', 'motivated', 'contenders', 'minority', 'proved', 'vote', 'overdue', 'expanding', 'though', 'school', 'uvalde', 'urged', 'effort', 'job', 'government', 'extend', 'death', '”', 'enforce', 'district', 'assailant', 'â€œprove', 'strengthened', 'york', 'tillis', 'partners', 'accused', 'citizensâ€™', '17-year', 'bans', 'eight', 'away', 'state', 'hailed', 'lawmakers', 'slayings', 'ted', 'safer', 'examinations', 'd-n.y', 'give', 'included', 'legislation', 'days', 'rear', 'nineteen', 'carolina', 'trafficking', 'thom', 'side', 'fund', 'potency', 'youngest', 'definition', 'broken', 'curbs', 'rise', 
# ...

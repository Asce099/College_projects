# %%
import nltk

# %%
help(nltk)
# Out:
# Help on package nltk:
#
# NAME
#     nltk
#
# DESCRIPTION
#     The Natural Language Toolkit (NLTK) is an open source Python library
#     for Natural Language Processing.  A free online book is available.
#     (If you use the library for academic research, please cite the book.)
#
#     Steven Bird, Ewan Klein, and Edward Loper (2009).
#     Natural Language Processing with Python.  O'Reilly Media Inc.
#     https://www.nltk.org/book/
#
#     isort:skip_file
#
#     @version: 3.7
#
# PACKAGE CONTENTS
#     app (package)
#     book
#     ccg (package)
#     chat (package)
#     chunk (package)
#     classify (package)
#     cli
#     cluster (package)
#     collections
#     collocations
#     compat
#     corpus (package)
#     data
#     decorators
#     downloader
#     draw (package)
#     featstruct
#     grammar
#     help
#     inference (package)
#     internals
#     jsontags
#     lazyimport
#     lm (package)
#     metrics (package)
#     misc (package)
# ...

# %%
nltk.help.upenn_tagset() # Penn Treebank PoS Tag
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
sentence = """At eight o'clock on Thursday morning Arthur didn't feel very good."""
sentence
# Out:
# "At eight o'clock on Thursday morning Arthur didn't feel very good."

# %% [markdown]
# # Tokens
#
# -an instance of a linguistic expression
#
# -a small part representing the whole

# %%
#import nltk.tokenize.simple
from nltk.tokenize.simple import *

# %%
help(nltk.tokenize.simple)
# Out:
# Help on module nltk.tokenize.simple in nltk.tokenize:
#
# NAME
#     nltk.tokenize.simple - Simple Tokenizers
#
# DESCRIPTION
#     These tokenizers divide strings into substrings using the string
#     ``split()`` method.
#     When tokenizing using a particular delimiter string, use
#     the string ``split()`` method directly, as this is more efficient.
#
#     The simple tokenizers are *not* available as separate functions;
#     instead, you should just use the string ``split()`` method directly:
#
#         >>> s = "Good muffins cost $3.88\nin New York.  Please buy me\ntwo of them.\n\nThanks."
#         >>> s.split()
#         ['Good', 'muffins', 'cost', '$3.88', 'in', 'New', 'York.',
#         'Please', 'buy', 'me', 'two', 'of', 'them.', 'Thanks.']
#         >>> s.split(' ')
#         ['Good', 'muffins', 'cost', '$3.88\nin', 'New', 'York.', '',
#         'Please', 'buy', 'me\ntwo', 'of', 'them.\n\nThanks.']
#         >>> s.split('\n')
# ...

# %%
tokens1=sentence.split()
tokens1
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  'Arthur',
#  "didn't",
#  'feel',
#  'very',
#  'good.']

# %%
# split(':'), split(': '), etc

# %%
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.']

# %%
tagged = nltk.pos_tag(tokens)  # PoS mapped to tokens
tagged
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN'),
#  ('Arthur', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('feel', 'VB'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.')]

# %%
tagged[0:5]
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP')]

# %%
entities = nltk.chunk.ne_chunk(tagged)

# %%
entities
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\.conda\envs\TA\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~\.conda\envs\TA\lib\site-packages\nltk\tree\tree.py:783, in Tree._repr_svg_(self)
#     782 def _repr_svg_(self):
# --> 783     from svgling import draw_tree
#     785     return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('S', [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), Tree('PERSON', [('Arthur', 'NNP')]), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')])

# %% [markdown]
# # svgling:
# syntax trees in python + svg

# %%
# !pip3 install svgling
# Out:
# ...
#      ---------------------------------------- 67.1/67.1 kB 3.6 MB/s eta 0:00:00
# ...

# %%
entities
# Out:
# Tree('S', [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), Tree('PERSON', [('Arthur', 'NNP')]), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')])

# %%
print(entities)
# Out:
# (S
#   At/IN
#   eight/CD
#   o'clock/NN
#   on/IN
#   Thursday/NNP
#   morning/NN
#   (PERSON Arthur/NNP)
#   did/VBD
#   n't/RB
#   feel/VB
#   very/RB
#   good/JJ
#   ./.)

# %%
help(nltk.tokenize)
# Out:
# Help on package nltk.tokenize in nltk:
#
# NAME
#     nltk.tokenize - NLTK Tokenizer Package
#
# DESCRIPTION
#     Tokenizers divide strings into lists of substrings.  For example,
#     tokenizers can be used to find the words and punctuation in a string:
#
#         >>> from nltk.tokenize import word_tokenize
#         >>> s = '''Good muffins cost $3.88\nin New York.  Please buy me
#         ... two of them.\n\nThanks.'''
#         >>> word_tokenize(s)
#         ['Good', 'muffins', 'cost', '$', '3.88', 'in', 'New', 'York', '.',
#         'Please', 'buy', 'me', 'two', 'of', 'them', '.', 'Thanks', '.']
#
#     This particular tokenizer requires the Punkt sentence tokenization
#     models to be installed. NLTK also provides a simpler,
#     regular-expression based tokenizer, which splits text on whitespace
#     and punctuation:
#
#         >>> from nltk.tokenize import wordpunct_tokenize
#         >>> wordpunct_tokenize(s)
# ...

# %%
tokens2 = nltk.sent_tokenize(sentence)
tokens2
# Out:
# ["At eight o'clock on Thursday morning Arthur didn't feel very good."]

# %%
sentence1 = """At eight o'clock on Thursday morning Arthur didn't feel very good. He Went to Hospital. Doctor advised him complete rest. The course of medicine given was of 5 days."""
sentence1
# Out:
# "At eight o'clock on Thursday morning Arthur didn't feel very good. He Went to Hospital. Doctor advised him complete rest. The course of medicine given was of 5 days."

# %%
tokens2 = nltk.sent_tokenize(sentence1)
tokens2
# Out:
# ["At eight o'clock on Thursday morning Arthur didn't feel very good.",
#  'He Went to Hospital.',
#  'Doctor advised him complete rest.',
#  'The course of medicine given was of 5 days.']

# %%
tagged2 = nltk.pos_tag(tokens2)  # PoS mapped to tokens
tagged2
# Out:
# [("At eight o'clock on Thursday morning Arthur didn't feel very good.", 'NNP'),
#  ('He Went to Hospital.', 'NNP'),
#  ('Doctor advised him complete rest.', 'NNP'),
#  ('The course of medicine given was of 5 days.', 'NNP')]

# %%
entities2 = nltk.chunk.ne_chunk(tagged2)
entities2
# Out:
# Tree('S', [("At eight o'clock on Thursday morning Arthur didn't feel very good.", 'NNP'), ('He Went to Hospital.', 'NNP'), ('Doctor advised him complete rest.', 'NNP'), ('The course of medicine given was of 5 days.', 'NNP')])

# %% [markdown]
# # Frequency Distribution

# %%
len(tokens)
# Out:
# 13

# %%
len(tokens2)
# Out:
# 4

# %%
distinct words use set

# %%
len(set(tokens))
# Out:
# 13

# %%
len(sentence1.split())
# Out:
# 29

# %%
len(set(sentence1.split()))
# Out:
# 28

# %%
nltk.FreqDist(tokens)
# Out:
# FreqDist({'At': 1, 'eight': 1, "o'clock": 1, 'on': 1, 'Thursday': 1, 'morning': 1, 'Arthur': 1, 'did': 1, "n't": 1, 'feel': 1, ...})

# %%
nltk.FreqDist(tokens2)
# Out:
# FreqDist({"At eight o'clock on Thursday morning Arthur didn't feel very good.": 1, 'He Went to Hospital.': 1, 'Doctor advised him complete rest.': 1, 'The course of medicine given was of 5 days.': 1})

# %%
nltk.FreqDist(sentence1.split())
# Out:
# FreqDist({'of': 2, 'At': 1, 'eight': 1, "o'clock": 1, 'on': 1, 'Thursday': 1, 'morning': 1, 'Arthur': 1, "didn't": 1, 'feel': 1, ...})

# %%
nltk.FreqDist(sentence1.split()).most_common()
# Out:
# [('of', 2),
#  ('At', 1),
#  ('eight', 1),
#  ("o'clock", 1),
#  ('on', 1),
#  ('Thursday', 1),
#  ('morning', 1),
#  ('Arthur', 1),
#  ("didn't", 1),
#  ('feel', 1),
#  ('very', 1),
#  ('good.', 1),
#  ('He', 1),
#  ('Went', 1),
#  ('to', 1),
#  ('Hospital.', 1),
#  ('Doctor', 1),
#  ('advised', 1),
#  ('him', 1),
#  ('complete', 1),
#  ('rest.', 1),
#  ('The', 1),
#  ('course', 1),
#  ('medicine', 1),
#  ('given', 1),
#  ('was', 1),
#  ('5', 1),
#  ('days.', 1)]

# %%
nltk.FreqDist(sentence1.split()).most_common(2)
# Out:
# [('of', 2), ('At', 1)]

# %%
sorted(tokens)
# Out:
# ['.',
#  'Arthur',
#  'At',
#  'Thursday',
#  'did',
#  'eight',
#  'feel',
#  'good',
#  'morning',
#  "n't",
#  "o'clock",
#  'on',
#  'very']

# %%
 fdist5 = FreqDist(text5)
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)

# %%
import os
from os import path

# %%
# Read the whole text from file.


#C:\Users\Ajey Kumar\Desktop\TA
#gunviob = open('C:/Users/Ajey Kumar/Desktop/TA/gunviolencebill.txt').read()

#gunviob = open('gunviolencebill.txt').read()
gunviob = open('C:/Users/Ajey Kumar/Desktop/TA/gunviolencebill.txt').read()

# %%
gunviob
# Out:
# 'US Senate passes landmark gun violence bill, House passage is next\nThe US Senate approved a bipartisan gun violence bill on Thursday in response to the run of brutal mass shootings. The measure would toughen background checks for youngest gun buyers and keep firearms away from more domestic violence offenders.\n\nThe Senate easily approved a bipartisan gun violence bill on Thursday that seemed unthinkable a month ago, setting up final approval of what will be Congressâ€™ most far-reaching response in decades to the nationâ€™s run of brutal mass shootings.\n\n\nAfter years of GOP procedural delays that derailed Democratic efforts to curb firearms, Democrats and 15 Republicans decided that congressional inaction was untenable after last monthâ€™s rampages in New York and Texas. It took weeks of closed-door talks but a bargainers from both parties emerged with a compromise embodying incremental but impactful movement to curb bloodshed that has come to regularly shock â€” yet no longer
# ...

# %%
tokens4 = nltk.word_tokenize(gunviob)
tokens4
# Out:
# ['US',
#  'Senate',
#  'passes',
#  'landmark',
#  'gun',
#  'violence',
#  'bill',
#  ',',
#  'House',
#  'passage',
#  'is',
#  'next',
#  'The',
#  'US',
#  'Senate',
#  'approved',
#  'a',
#  'bipartisan',
#  'gun',
#  'violence',
#  'bill',
#  'on',
#  'Thursday',
#  'in',
#  'response',
#  'to',
#  'the',
#  'run',
#  'of',
#  'brutal',
#  'mass',
#  'shootings',
#  '.',
#  'The',
#  'measure',
#  'would',
#  'toughen',
#  'background',
#  'checks',
#  'for',
#  'youngest',
#  'gun',
#  'buyers',
#  'and',
#  'keep',
#  'firearms',
#  'away',
#  'from',
#  'more',
#  'domestic',
#  'violence',
#  'offenders',
#  '.',
#  'The',
#  'Senate',
#  'easily',
#  'approved',
#  'a',
#  'bipartisan',
#  'gun',
#  'violence',
#  'bill',
#  'on',
#  'Thursday',
#  'that',
#  'seemed',
#  'unthinkable',
#  'a',
#  'month',
#  'ago',
#  ',',
#  'setting',
#  'up',
#  'final',
#  'approval',
#  'of',
#  'what',
#  'will',
#  'be',
#  'Congressâ€™',
#  'most',
#  'far-reaching',
# ...

# %%
len(tokens4)
# Out:
# 1362

# %%
len(set(tokens4))
# Out:
# 610

# %%
tokens5 = nltk.sent_tokenize(gunviob)
tokens5
# Out:
# ['US Senate passes landmark gun violence bill, House passage is next\nThe US Senate approved a bipartisan gun violence bill on Thursday in response to the run of brutal mass shootings.',
#  'The measure would toughen background checks for youngest gun buyers and keep firearms away from more domestic violence offenders.',
#  'The Senate easily approved a bipartisan gun violence bill on Thursday that seemed unthinkable a month ago, setting up final approval of what will be Congressâ€™ most far-reaching response in decades to the nationâ€™s run of brutal mass shootings.',
#  'After years of GOP procedural delays that derailed Democratic efforts to curb firearms, Democrats and 15 Republicans decided that congressional inaction was untenable after last monthâ€™s rampages in New York and Texas.',
# ...

# %%
len(tokens5)
# Out:
# 53

# %%
len(set(tokens5))
# Out:
# 53

# %%
fdist=nltk.FreqDist(tokens4)
fdist
# Out:
# FreqDist({'the': 55, ',': 54, '.': 53, 'to': 41, 'of': 38, 'and': 36, 'a': 27, 'in': 24, 'for': 19, 'that': 16, ...})

# %%
fdist.most_common(5)
# Out:
# [('the', 55), (',', 54), ('.', 53), ('to', 41), ('of', 38)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Spacy

# %%
# !pip3 install -U spacy
# Out:
# ...
#      ---------------------------------------- 11.7/11.7 MB 5.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.9/1.9 MB 5.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 448.4/448.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.8/62.8 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# ...
#      -------------------------------------- 181.6/181.6 kB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.6/6.6 MB 4.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 112.4/112.4 kB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.6/58.6 kB 3.0 MB/s eta 0:00:00
# ...
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# ...
#      -------------------------------------- 139.0/139.0 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import spacy

# %%
help(spacy)
# Out:
# Help on package spacy:
#
# NAME
#     spacy
#
# PACKAGE CONTENTS
#     __main__
#     about
#     attrs
#     cli (package)
#     compat
#     displacy (package)
#     errors
#     git_info
#     glossary
#     kb
#     lang (package)
#     language
#     lexeme
#     lookups
#     matcher (package)
#     ml (package)
#     morphology
#     parts_of_speech
#     pipe_analysis
#     pipeline (package)
#     schemas
#     scorer
#     strings
#     symbols
#     tests (package)
#     tokenizer
#     tokens (package)
#     training (package)
#     ty
#     util
#     vectors
#     vocab
#
# FUNCTIONS
#     blank(name: str, *, vocab: Union[spacy.vocab.Vocab, bool] = True, config: Union[Dict[str, Any], thinc.config.Config] = {}, meta: Dict[str, Any] = {}) -> spacy.language.Language
#         Create a blank nlp object for a given language code.
#
#         name (str): The language code, e.g. "en".
#         vocab (Vocab): A Vocab object. If True, a vocab is created.
# ...

# %%
from spacy import displacy

# %%
print(spacy.language)
# Out:
# <module 'spacy.language' from 'C:\\Users\\Ajey Kumar\\.conda\\envs\\TA\\lib\\site-packages\\spacy\\language.py'>

# %%
for ln in spacy.language:
    print(ln)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 for ln in spacy.language:
#       2     print(ln)
#
# TypeError: 'module' object is not iterable

# %%
for ln in spacy.lang:
    print(ln)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 for ln in spacy.lang:
#       2     print(ln)
#
# TypeError: 'module' object is not iterable

# %%
help(spacy.lang)
# Out:
# Help on package spacy.lang in spacy:
#
# NAME
#     spacy.lang
#
# PACKAGE CONTENTS
#     af (package)
#     am (package)
#     ar (package)
#     az (package)
#     bg (package)
#     bn (package)
#     ca (package)
#     char_classes
#     cs (package)
#     da (package)
#     de (package)
#     dsb (package)
#     el (package)
#     en (package)
#     es (package)
#     et (package)
#     eu (package)
#     fa (package)
#     fi (package)
#     fr (package)
#     ga (package)
#     grc (package)
#     gu (package)
#     he (package)
#     hi (package)
#     hr (package)
#     hsb (package)
#     hu (package)
#     hy (package)
#     id (package)
#     is (package)
#     it (package)
#     ja (package)
#     kn (package)
#     ko (package)
#     ky (package)
#     lb (package)
#     lex_attrs
#     lij (package)
#     lt (package)
#     lv (package)
#     mk (package)
#     ml (package)
#     mr (package)
#     nb (package)
#     ne (package)
#     nl (package)
# ...

# %%
help(spacy.language)
# Out:
# Help on module spacy.language in spacy:
#
# NAME
#     spacy.language
#
# CLASSES
#     builtins.list(builtins.object)
#         DisabledPipes
#     builtins.object
#         BaseDefaults
#         FactoryMeta
#         Language
#
#     class BaseDefaults(builtins.object)
#      |  Language data defaults, available via Language.Defaults. Can be
#      |  overwritten by language subclasses by defining their own subclasses of
#      |  Language.Defaults.
#      |
#      |  Static methods defined here:
#      |
#      |  url_match = match(string, pos=0, endpos=9223372036854775807) from re.Pattern
#      |      Matches zero or more characters at the beginning of the string.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
# ...

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 nlp = spacy.load("en")
#
# File ~\.conda\envs\TA\lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      36     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      37 ) -> Language:
#      38     """Load a spaCy model from an installed package or a local path.
#      39
#      40     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ...

# %%
'''
# !python -m spacy download en_core_web_sm

After This 
nlp = spacy.load("en_core_web_sm")
OR
import en_core_web_sm
nlp = en_core_web_sm.load()
'''

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      -------------------------------------- 12.8/12.8 MB 299.4 kB/s eta 0:00:00
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(u"At eight o'clock on Thursday morning Arthur didn't feel very good.")
doc
# Out:
# At eight o'clock on Thursday morning Arthur didn't feel very good.

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# At ADP
# eight NUM
# o'clock NOUN
# on ADP
# Thursday PROPN
# morning NOUN
# Arthur PROPN
# did AUX
# n't PART
# feel VERB
# very ADV
# good ADJ
# . PUNCT

# %%
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="df7a147b82b84a14b37424c7f142d4fe-0" class="displacy" width="2150" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">At</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">eight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
https://spacy.io/usage/models
https://spacy.io/models/en
#https://spacy.io/usage/linguistic-features
https://www.analyticsvidhya.com/blog/2020/03/spacy-tutorial-learn-natural-language-processing/
https://realpython.com/natural-language-processing-spacy-python/
https://www.tutorialspoint.com/spacy/spacy_models_and_languages.htm    
https://www.machinelearningplus.com/spacy-tutorial-nlp/
https://blog.dominodatalab.com/natural-language-in-python-using-spacy

# %% [markdown]
# # Textblob

# %%
# !pip3 install textblob
# Out:
# ...
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# ...

# %%
from textblob import TextBlob

# %%
wiki = TextBlob("At eight o'clock on Thursday morning Arthur didn't feel very good.")
wiki
# Out:
# TextBlob("At eight o'clock on Thursday morning Arthur didn't feel very good.")

# %%
wiki.tags
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN'),
#  ('Arthur', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('feel', 'VB'),
#  ('very', 'RB'),
#  ('good', 'JJ')]

# %%
wiki.parse()
# Out:
# "At/IN/B-PP/O eight/CD/O/O o/IN/B-PP/O '/POS/O/O clock/NN/B-NP/O on/IN/B-PP/B-PNP Thursday/NNP/B-NP/I-PNP morning/NN/I-NP/I-PNP Arthur/NNP/I-NP/I-PNP did/VBD/B-VP/O n/NN/B-NP/O '/POS/O/O t/NN/B-NP/O feel/VB/B-VP/O very/RB/B-ADJP/O good/JJ/I-ADJP/O ././O/O"

# %%
wiki.pos_tags
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN'),
#  ('Arthur', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('feel', 'VB'),
#  ('very', 'RB'),
#  ('good', 'JJ')]

# %%
help(TextBlob)
# Out:
# Help on class TextBlob in module textblob.blob:
#
# class TextBlob(BaseBlob)
#  |  TextBlob(text, tokenizer=None, pos_tagger=None, np_extractor=None, analyzer=None, parser=None, classifier=None, clean_html=False)
#  |
#  |  A general text block, meant for larger bodies of text (esp. those
#  |  containing sentences). Inherits from :class:`BaseBlob <BaseBlob>`.
#  |
#  |  :param str text: A string.
#  |  :param tokenizer: (optional) A tokenizer instance. If ``None``, defaults to
#  |      :class:`WordTokenizer() <textblob.tokenizers.WordTokenizer>`.
#  |  :param np_extractor: (optional) An NPExtractor instance. If ``None``,
#  |      defaults to :class:`FastNPExtractor() <textblob.en.np_extractors.FastNPExtractor>`.
#  |  :param pos_tagger: (optional) A Tagger instance. If ``None``, defaults to
#  |      :class:`NLTKTagger <textblob.en.taggers.NLTKTagger>`.
#  |  :param analyzer: (optional) A sentiment analyzer. If ``None``, defaults to
# ...

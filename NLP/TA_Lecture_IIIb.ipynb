# %% [markdown]
# # Named Entity Recognization (NER)

# %%
# using NLTK

# %%
import nltk

# %%
sentence = """At eight o'clock on Thursday morning Arthur didn't feel very good."""
sentence
# Out:
# "At eight o'clock on Thursday morning Arthur didn't feel very good."

# %%
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.']

# %%
tagged = nltk.pos_tag(tokens)  # PoS mapped to tokens
tagged
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN'),
#  ('Arthur', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('feel', 'VB'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities
# Out:
# Tree('S', [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), Tree('PERSON', [('Arthur', 'NNP')]), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')])

# %%
for chunk in entities:
     if hasattr(chunk, 'label'):
        print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# PERSON Arthur

# %%
from os import path

# %%
gunviob = open('C:/Users/Ajey Kumar/Desktop/TA/gunviolencebill.txt').read()

# %%
gunviob
# Out:
# 'US Senate passes landmark gun violence bill, House passage is next\nThe US Senate approved a bipartisan gun violence bill on Thursday in response to the run of brutal mass shootings. The measure would toughen background checks for youngest gun buyers and keep firearms away from more domestic violence offenders.\n\nThe Senate easily approved a bipartisan gun violence bill on Thursday that seemed unthinkable a month ago, setting up final approval of what will be Congressâ€™ most far-reaching response in decades to the nationâ€™s run of brutal mass shootings.\n\n\nAfter years of GOP procedural delays that derailed Democratic efforts to curb firearms, Democrats and 15 Republicans decided that congressional inaction was untenable after last monthâ€™s rampages in New York and Texas. It took weeks of closed-door talks but a bargainers from both parties emerged with a compromise embodying incremental but impactful movement to curb bloodshed that has come to regularly shock â€” yet no longer
# ...

# %%
tokens4 = nltk.word_tokenize(gunviob)
tokens4
# Out:
# ['US',
#  'Senate',
#  'passes',
#  'landmark',
#  'gun',
#  'violence',
#  'bill',
#  ',',
#  'House',
#  'passage',
#  'is',
#  'next',
#  'The',
#  'US',
#  'Senate',
#  'approved',
#  'a',
#  'bipartisan',
#  'gun',
#  'violence',
#  'bill',
#  'on',
#  'Thursday',
#  'in',
#  'response',
#  'to',
#  'the',
#  'run',
#  'of',
#  'brutal',
#  'mass',
#  'shootings',
#  '.',
#  'The',
#  'measure',
#  'would',
#  'toughen',
#  'background',
#  'checks',
#  'for',
#  'youngest',
#  'gun',
#  'buyers',
#  'and',
#  'keep',
#  'firearms',
#  'away',
#  'from',
#  'more',
#  'domestic',
#  'violence',
#  'offenders',
#  '.',
#  'The',
#  'Senate',
#  'easily',
#  'approved',
#  'a',
#  'bipartisan',
#  'gun',
#  'violence',
#  'bill',
#  'on',
#  'Thursday',
#  'that',
#  'seemed',
#  'unthinkable',
#  'a',
#  'month',
#  'ago',
#  ',',
#  'setting',
#  'up',
#  'final',
#  'approval',
#  'of',
#  'what',
#  'will',
#  'be',
#  'Congressâ€™',
#  'most',
#  'far-reaching',
# ...

# %%
tagged4 = nltk.pos_tag(tokens4)  # PoS mapped to tokens
tagged4
# Out:
# [('US', 'NNP'),
#  ('Senate', 'NNP'),
#  ('passes', 'VBZ'),
#  ('landmark', 'NN'),
#  ('gun', 'NN'),
#  ('violence', 'NN'),
#  ('bill', 'NN'),
#  (',', ','),
#  ('House', 'NNP'),
#  ('passage', 'NN'),
#  ('is', 'VBZ'),
#  ('next', 'JJ'),
#  ('The', 'DT'),
#  ('US', 'NNP'),
#  ('Senate', 'NNP'),
#  ('approved', 'VBD'),
#  ('a', 'DT'),
#  ('bipartisan', 'JJ'),
#  ('gun', 'NN'),
#  ('violence', 'NN'),
#  ('bill', 'NN'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('in', 'IN'),
#  ('response', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('run', 'NN'),
#  ('of', 'IN'),
#  ('brutal', 'JJ'),
#  ('mass', 'NN'),
#  ('shootings', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('measure', 'NN'),
#  ('would', 'MD'),
#  ('toughen', 'VB'),
#  ('background', 'NN'),
#  ('checks', 'NNS'),
#  ('for', 'IN'),
#  ('youngest', 'JJS'),
#  ('gun', 'NN'),
#  ('buyers', 'NNS'),
#  ('and', 'CC'),
#  ('keep', 'VB'),
#  ('firearms', 'NNS'),
#  ('away', 'RB'),
#  ('from', 'IN'),
#  ('more', 'RBR'),
# ...

# %%
entities4 = nltk.chunk.ne_chunk(tagged4)
entities4
# Out:
# Tree('S', [Tree('GPE', [('US', 'NNP')]), Tree('ORGANIZATION', [('Senate', 'NNP')]), ('passes', 'VBZ'), ('landmark', 'NN'), ('gun', 'NN'), ('violence', 'NN'), ('bill', 'NN'), (',', ','), Tree('ORGANIZATION', [('House', 'NNP')]), ('passage', 'NN'), ('is', 'VBZ'), ('next', 'JJ'), ('The', 'DT'), Tree('ORGANIZATION', [('US', 'NNP')]), Tree('ORGANIZATION', [('Senate', 'NNP')]), ('approved', 'VBD'), ('a', 'DT'), ('bipartisan', 'JJ'), ('gun', 'NN'), ('violence', 'NN'), ('bill', 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('in', 'IN'), ('response', 'NN'), ('to', 'TO'), ('the', 'DT'), ('run', 'NN'), ('of', 'IN'), ('brutal', 'JJ'), ('mass', 'NN'), ('shootings', 'NNS'), ('.', '.'), ('The', 'DT'), ('measure', 'NN'), ('would', 'MD'), ('toughen', 'VB'), ('background', 'NN'), ('checks', 'NNS'), ('for', 'IN'), ('youngest', 'JJS'), ('gun', 'NN'), ('buyers', 'NNS'), ('and', 'CC'), ('keep', 'VB'), ('firearms', 'NNS'), ('away', 'RB'), ('from', 'IN'), ('more', 'RBR'), ('domestic', 'JJ'), ('violence', 'NN'),
# ...

# %%
for chunk in entities4:
     if hasattr(chunk, 'label'):
        print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# GPE US
# ORGANIZATION Senate
# ORGANIZATION House
# ORGANIZATION US
# ORGANIZATION Senate
# ORGANIZATION Senate
# ORGANIZATION GOP
# ORGANIZATION Democratic
# ORGANIZATION Democrats
# GPE New York
# GPE Texas
# GPE Buffalo
# GPE New York
# GPE Uvalde
# GPE Texas
# ORGANIZATION Senate
# PERSON Chuck Schumer
# GPE D-N.Y.
# ORGANIZATION Senate
# PERSON Mitch McConnell
# ORGANIZATION Second
# GPE American
# ORGANIZATION Senate
# ORGANIZATION cIout
# ORGANIZATION Supreme Court
# GPE Americans
# GPE New York
# ORGANIZATION McConnell
# ORGANIZATION Senate
# ORGANIZATION Senate
# ORGANIZATION House
# ORGANIZATION GOP
# ORGANIZATION House
# ORGANIZATION Senate
# ORGANIZATION National Rifle Association
# PERSON Lisa Murkowski
# GPE Alaska
# PERSON Todd Young
# GPE Indiana
# ORGANIZATION GOP
# ORGANIZATION Ted Cruz
# GPE Texas
# PERSON Josh Hawley
# GPE Missouri
# PERSON Tim Scott
# GPE South Carolina
# ORGANIZATION Sens
# PERSON Rand Paul
# GPE Kentucky
# PERSON Mike Lee
# GPE Utah
# ...

# %%
help(nltk.chunk)
# Out:
# Help on package nltk.chunk in nltk:
#
# NAME
#     nltk.chunk
#
# DESCRIPTION
#     Classes and interfaces for identifying non-overlapping linguistic
#     groups (such as base noun phrases) in unrestricted text.  This task is
#     called "chunk parsing" or "chunking", and the identified groups are
#     called "chunks".  The chunked text is represented using a shallow
#     tree called a "chunk structure."  A chunk structure is a tree
#     containing tokens and chunks, where each chunk is a subtree containing
#     only tokens.  For example, the chunk structure for base noun phrase
#     chunks in the sentence "I saw the big dog on the hill" is::
#
#       (SENTENCE:
#         (NP: <I>)
#         <saw>
#         (NP: <the> <big> <dog>)
#         <on>
#         (NP: <the> <hill>))
#
#     To convert a chunk structure back to a list of tokens, simply use the
#     chunk structure's ``leaves()`` method.
#
#     This module defines ``ChunkParserI``, a standard interface for
# ...

# %%
help(nltk.chunk.named_entity)
# Out:
# Help on module nltk.chunk.named_entity in nltk.chunk:
#
# NAME
#     nltk.chunk.named_entity - Named entity chunker
#
# CLASSES
#     nltk.chunk.api.ChunkParserI(nltk.parse.api.ParserI)
#         NEChunkParser
#     nltk.tag.sequential.ClassifierBasedTagger(nltk.tag.sequential.SequentialBackoffTagger, nltk.tag.api.FeaturesetTaggerI)
#         NEChunkParserTagger
#
#     class NEChunkParser(nltk.chunk.api.ChunkParserI)
#      |  NEChunkParser(train)
#      |
#      |  Expected input: list of pos-tagged words
#      |
#      |  Method resolution order:
#      |      NEChunkParser
#      |      nltk.chunk.api.ChunkParserI
#      |      nltk.parse.api.ParserI
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, train)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  parse(self, tokens)
#      |      Each token should be a pos-tagged word
#      |
# ...

# %%
help(nltk.chunk.ne_chunk)
# Out:
# Help on function ne_chunk in module nltk.chunk:
#
# ne_chunk(tagged_tokens, binary=False)
#     Use NLTK's currently recommended named entity chunker to
#     chunk the given list of tagged tokens.

# %%
Common entity types include ORGANIZATION, PERSON, LOCATION, DATE, TIME, MONEY, and GPE (geo-political entity).

# %%
#using Spacy

# %%
import spacy

# %%
from spacy import displacy

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(u"At eight o'clock on Thursday morning Arthur didn't feel very good.")
doc
# Out:
# At eight o'clock on Thursday morning Arthur didn't feel very good.

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# At ADP
# eight NUM
# o'clock NOUN
# on ADP
# Thursday PROPN
# morning NOUN
# Arthur PROPN
# did AUX
# n't PART
# feel VERB
# very ADV
# good ADJ
# . PUNCT

# %%
print(doc.ents)
# Out:
# (eight o'clock, Thursday, Arthur)

# %%
for entity in doc.ents:
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# eight o'clock - TIME - Times smaller than a day
# Thursday - DATE - Absolute or relative dates or periods
# Arthur - ORG - Companies, agencies, institutions, etc.

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">At
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight o'clock
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  morning
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arthur
# ...

# %%
displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">At
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight o'clock
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  morning
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arthur
# ...

# %%
doc2=nlp(gunviob)

# %%
print(doc2.ents)
# Out:
# (US Senate, House, The US Senate, Thursday, Senate, Thursday, a month ago, decades, nationâ€, ™, years, GOP, Democratic, Democrats, 15, Republicans, last monthâ€™, New York, Texas, weeks, $13 billion, election-year, Democrats, Republicans, years, Buffalo, New York, Uvalde, Texas, Senate, Chuck Schumer, D-N.Y., decades, Senate, Mitch McConnell, R-Ky., the Second Amendment, American, Senate, cIout, Supreme Court, Americans, New York, McConnell, Senate, Senate, 65-33, House, Democrats, Lucy McBath, D-Ga., 17-year old, 2012, 65-34, GOP, five, 60, House, Friday, 15, Senate, Republicans, 50, Democrats, two, Republicans, the National Rifle Association, Lisa Murkowski, Alaska, Todd Young, Indiana, only two, 15, this fall, four, eight, 2026, GOP, â€œno, 2024, Ted Cruz, Texas, Josh Hawley, Missouri, Tim Scott, South Carolina, â€œno, Kentucky, Mike Lee, Utah, Senate, Less than one-third, ™, 50, GOP, Republican, House, House, Republicans, 2, GOP, Steve Scalise, Louisiana, 2nd Amendment rights, D
# ...

# %%
for entity in doc2.ents:
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# US Senate - ORG - Companies, agencies, institutions, etc.
# House - ORG - Companies, agencies, institutions, etc.
# The US Senate - ORG - Companies, agencies, institutions, etc.
# Thursday - DATE - Absolute or relative dates or periods
# Senate - ORG - Companies, agencies, institutions, etc.
# Thursday - DATE - Absolute or relative dates or periods
# a month ago - DATE - Absolute or relative dates or periods
# decades - DATE - Absolute or relative dates or periods
# nationâ€ - ORG - Companies, agencies, institutions, etc.
# ™ - MONEY - Monetary values, including unit
# years - DATE - Absolute or relative dates or periods
# GOP - ORG - Companies, agencies, institutions, etc.
# Democratic - NORP - Nationalities or religious or political groups
# Democrats - NORP - Nationalities or religious or political groups
# 15 - CARDINAL - Numerals that do not fall under another type
# Republicans - NORP - Nationalities or religious or political groups
# ...

# %%
'''
if we want to try this on real large datasets, we can use the medium and large models in spacy.
nlp = spacy.load('en_core_web_md')
nlp = spacy.load('en_core_web_lg')

'''
# Out:
# "\nif we want to try this on real large datasets, we can use the medium and large models in spacy.\nnlp = spacy.load('en_core_web_md')\nnlp = spacy.load('en_core_web_lg')\n\n"

# %%
spacy.displacy.render(doc2, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US Senate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  passes landmark gun violence bill,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  passage is next</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The US Senate
# ...

# %%
spacy.explain(u"NORP")
# Out:
# 'Nationalities or religious or political groups'

# %%
from collections import Counter

# %%
labels = [x.label_ for x in doc2.ents]
Counter(labels)
# Out:
# Counter({'ORG': 35,
#          'DATE': 23,
#          'MONEY': 5,
#          'NORP': 15,
#          'CARDINAL': 23,
#          'GPE': 23,
#          'PERSON': 18,
#          'LAW': 2,
#          'PRODUCT': 1})

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Adding New Entities in Spacy
# https://stackabuse.com/python-for-nlp-parts-of-speech-tagging-and-named-entity-recognition/

# %% [markdown]
# # Using Textblob

# %%
#Find out and do yourself

# %%
# Useful Reseources
https://www.guru99.com/pos-tagging-chunking-nltk.html
https://nanonets.com/blog/named-entity-recognition-with-nltk-and-spacy/#:~:text=(Source%3A%20nltk)-,NER%20with%20nltk,in%20terms%20of%20additional%20configurations.
https://analyticsindiamag.com/guide-to-named-entity-recognition-with-spacy-and-nltk/

# %%
https://chatterbot.readthedocs.io/en/stable/

# %%
# !pip3 install chatterbot  # it this doesn't work, Pls install from command prompt  pip install --upgrade chatterbot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Chatterbot comes with a data utility module that can be used to train the chatbots.
# At the moment there is training data for more than a dozen languages in this module.
# https://github.com/gunthercox/chatterbot-corpus

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 2.0/2.0 MB 2.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.1
#     Uninstalling pip-22.2.1:
#       Successfully uninstalled pip-22.2.1
# ...
#   WARNING: The scripts pip.exe, pip3.9.exe and pip3.exe are installed in 'C:\Users\Sai\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip3 install chatterbot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 67.8/67.8 kB 528.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 292.0/292.0 kB 1.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [322 lines of output]
# ...
#     Using cached setuptools-65.3.0-py3-none-any.whl (1.2 MB)
# ...
#        -------------------------------------- 986.3/986.3 kB 1.6 MB/s eta 0:00:00
# ...
#     Using cached cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# ...

# %%
pip install chatterbot_corpus

# %%
import chatterbot

# %%
chatterbot.__version__
# Out:
# '1.0.4'

# %%
help(chatterbot)
# Out:
# Help on package chatterbot:
#
# NAME
#     chatterbot - ChatterBot is a machine learning, conversational dialog engine.
#
# PACKAGE CONTENTS
#     __main__
#     adapters
#     chatterbot
#     comparisons
#     constants
#     conversation
#     corpus
#     ext (package)
#     filters
#     languages
#     logic (package)
#     parsing
#     preprocessors
#     response_selection
#     search
#     storage (package)
#     tagging
#     trainers
#     utils
#
# CLASSES
#     builtins.object
#         chatterbot.chatterbot.ChatBot
#
#     class ChatBot(builtins.object)
#      |  ChatBot(name, **kwargs)
#      |
#      |  A conversational dialog chat bot.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, name, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  generate_response(self, input_statement, additional_response_selection_parameters=None)
# ...

# %%
from chatterbot import chatbot
from chatterbot.trainers import ListTrainer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-423f775d9e3e> in <module>
# ----> 1 from chatterbot import chatbot
#       2 from chatterbot.trainers import ListTrainer
#
# ImportError: cannot import name 'chatbot' from 'chatterbot' (C:\anaconda\envs\textAnalytics\lib\site-packages\chatterbot\__init__.py)

# %%
from chatterbot import chatterbot

# %%
from chatterbot.trainers import ListTrainer

# %%
help(ListTrainer)
# Out:
# Help on class ListTrainer in module chatterbot.trainers:
#
# class ListTrainer(Trainer)
#  |  ListTrainer(chatbot, **kwargs)
#  |
#  |  Allows a chat bot to be trained using a list of strings
#  |  where the list represents a conversation.
#  |
#  |  Method resolution order:
#  |      ListTrainer
#  |      Trainer
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  train(self, conversation)
#  |      Train the chat bot based on the provided list of
#  |      statements that represents a single conversation.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Trainer:
#  |
#  |  __init__(self, chatbot, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  export_for_training(self, file_path='./export.json')
#  |      Create a file from the database that can be used to
#  |      train other chat bots.
#  |
#  |  get_preprocessed_statement(self, input_statement)
# ...

# %%
#creating a new chatbot
chatbot = chatterbot.ChatBot('SCIT')
trainer = ListTrainer(chatbot)
trainer.train([ 'hi, can I help you find a course', "sure I'd love to find you a course", 'your course have been selected'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-81fe7e5069da> in <module>
#       1 #creating a new chatbot
# ----> 2 chatbot = chatterbot.ChatBot('SCIT')
#       3 trainer = ListTrainer(chatbot)
#       4 trainer.train([ 'hi, can I help you find a course', "sure I'd love to find you a course", 'your course have been selected'])
#       5
#
# C:\anaconda\envs\textAnalytics\lib\site-packages\chatterbot\chatterbot.py in __init__(self, name, **kwargs)
#      32         self.logic_adapters = []
#      33
# ---> 34         self.storage = utils.initialize_class(storage_adapter, **kwargs)
#      35
#      36         for adapter in logic_adapters:
#
# C:\anaconda\envs\textAnalytics\lib\site-packages\chatterbot\utils.py in initialize_class(data, *args, **kwargs)
#      52         Class = import_module(data)
#      53
# ---> 54         return Class(*args, **kwargs)
# ...

# %%
from chatterbot.chatterbot import ChatBot

# %% [markdown]
# As per  https://stackoverflow.com/questions/62609296/solution-for-attributeerror-module-time-has-no-attribute-clock
#
# In the compat.py file available at C:\anaconda\envs\textAnalytics\lib\site-packages\sqlalchemy\util\compat.py ( path may change in your environment)
#
# do the following corrections as shoun in the image

# %% [markdown]
# ![error.jpg](attachment:error.jpg)

# %%
chatbot = ChatBot('SCIT')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Ajey Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to C:\Users\Ajey
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Ajey
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
help(ChatBot)
# Out:
# Help on class ChatBot in module chatterbot.chatterbot:
#
# class ChatBot(builtins.object)
#  |  ChatBot(name, **kwargs)
#  |
#  |  A conversational dialog chat bot.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  generate_response(self, input_statement, additional_response_selection_parameters=None)
#  |      Return a response based on a given input statement.
#  |
#  |      :param input_statement: The input statement to be processed.
#  |
#  |  get_initialization_functions(self)
#  |
#  |  get_latest_response(self, conversation)
#  |      Returns the latest response in a conversation if it exists.
#  |      Returns None if a matching conversation cannot be found.
#  |
#  |  get_response(self, statement=None, **kwargs)
#  |      Return the bot's response based on the input.
#  |
#  |      :param statement: An statement object or string.
# ...

# %%
from chatterbot.adapters import *

# %%
help(chatterbot.adapters)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-77b1a1e27579> in <module>
# ----> 1 help(chatterbot.adapters)
#
# AttributeError: module 'chatterbot.chatterbot' has no attribute 'adapters'

# %%
help(chatterbot.logic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-2f6d9723a6d1> in <module>
# ----> 1 help(chatterbot.logic)
#
# AttributeError: module 'chatterbot.chatterbot' has no attribute 'logic'

# %%
import chatterbot_corpus

# %%
from chatterbot_corpus import *

# %%
help(chatterbot_corpus)
# Out:
# Help on package chatterbot_corpus:
#
# NAME
#     chatterbot_corpus - A machine readable multilingual dialog corpus.
#
# PACKAGE CONTENTS
#     corpus
#
# DATA
#     __email__ = 'gunthercx@gmail.com'
#     __url__ = 'https://github.com/gunthercox/chatterbot-corpus'
#
# VERSION
#     1.2.0
#
# AUTHOR
#     Gunther Cox
#
# FILE
#     c:\anaconda\envs\textanalytics\lib\site-packages\chatterbot_corpus\__init__.py

# %%
import time

# %%
help(time)
# Out:
# Help on built-in module time:
#
# NAME
#     time - This module provides various functions to manipulate time values.
#
# DESCRIPTION
#     There are two standard representations of time.  One is the number
#     of seconds since the Epoch, in UTC (a.k.a. GMT).  It may be an integer
#     or a floating point number (to represent fractions of seconds).
#     The Epoch is system-defined; on Unix, it is generally January 1st, 1970.
#     The actual value can be retrieved by calling gmtime(0).
#
#     The other representation is a tuple of 9 integers giving local time.
#     The tuple items are:
#       year (including century, e.g. 1998)
#       month (1-12)
#       day (1-31)
#       hours (0-23)
#       minutes (0-59)
#       seconds (0-59)
#       weekday (0-6, Monday is 0)
#       Julian day (day in the year, 1-366)
#       DST (Daylight Savings Time) flag (-1, 0 or 1)
#     If the DST flag is 0, the time is given in the regular time zone;
# ...

# %%
# try the code from https://www.datacamp.com/community/tutorials/building-a-chatbot-using-chatterbot
